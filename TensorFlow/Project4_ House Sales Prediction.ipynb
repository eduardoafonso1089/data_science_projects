# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns

# %% [markdown]
# # Import database

# %%
house = pd.read_csv('kc-house-data.csv')

# %%
house.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %%
house.tail()
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21608        1530              0      2009             0    98103  47.6993
# 21609        2310              0      2014             0    98146  47.5107
# 21610        1020              0      2009             0    98144  47.5944
# 21611        1600              0      2004             0    98027  47.5345
# 21612        1020              0      2008             0    98144  47.5941
#
#           long  sqft_living15  sqft_lot15
# 21608 -122.346           1530        1509
# 21609 -122.362           1830        7200
# 21610 -122.299           1020        2007
# 21611 -122.069           1410        1287
# 21612 -122.299           1020        1357
#
# [5 rows x 21 columns]

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
#  17  lat            21613 non-null  float64
#  18  long           21613 non-null  float64
#  19  sqft_living15  21613 non-null  int64
#  20  sqft_lot15     21613 non-null  int64
# dtypes: float64(5), int64(15), object(1)
# memory usage: 3.5+ MB

# %%
house.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# std    4.142051e+04      0.539989      0.086517      0.766318      0.650743
# min    5.200000e+02      1.000000      0.000000      0.000000      1.000000
# 25%    5.040000e+03      1.000000      0.000000      0.000000      3.000000
# 50%    7.618000e+03      1.500000      0.000000      0.000000      3.000000
# 75%    1.068800e+04      2.000000      0.000000      0.000000      4.000000
# max    1.651359e+06      3.500000      1.000000      4.000000      5.000000
#
#               grade    sqft_above  sqft_basement      yr_built  yr_renovated  \
# count  21613.000000  21613.000000   21613.000000  21613.000000  21613.000000
# mean       7.656873   1788.390691     291.509045   1971.005136     84.402258
# std        1.175459    828.090978     442.575043     29.373411    401.679240
# min        1.000000    290.000000       0.000000   1900.000000      0.000000
# 25%        7.000000   1190.000000       0.000000   1951.000000      0.000000
# 50%        7.000000   1560.000000       0.000000   1975.000000      0.000000
# 75%        8.000000   2210.000000     560.000000   1997.000000      0.000000
# max       13.000000   9410.000000    4820.000000   2015.000000   2015.000000
#
#             zipcode           lat          long  sqft_living15     sqft_lot15
# count  21613.000000  21613.000000  21613.000000   21613.000000   21613.000000
# mean   98077.939805     47.560053   -122.213896    1986.552492   12768.455652
# std       53.505026      0.138564      0.140828     685.391304   27304.179631
# min    98001.000000     47.155900   -122.519000     399.000000     651.000000
# 25%    98033.000000     47.471000   -122.328000    1490.000000    5100.000000
# 50%    98065.000000     47.571800   -122.230000    1840.000000    7620.000000
# 75%    98118.000000     47.678000   -122.125000    2360.000000   10083.000000
# max    98199.000000     47.777600   -121.315000    6210.000000  871200.000000

# %% [markdown]
# # Cleaning database

# %%
house = house.drop('date', axis=1)

# %%
sns.scatterplot(x= 'sqft_living', y= 'price', data= house)
# Out:
# <Axes: xlabel='sqft_living', ylabel='price'>

# %%
f, ax = plt.subplots(figsize=(20, 20))
corr = house.corr()
sns.heatmap(corr, annot= True)
# Out:
# <Axes: >

# %%
house.hist(bins = 20, figsize=(20,20), color = 'b');

# %%
sns.pairplot(house)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # Processing data

# %%
selected_features = ['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'sqft_above', 'sqft_basement']

# %%
x = house[selected_features]
x.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  sqft_above  \
# 0         3       1.00         1180      5650     1.0        1180
# 1         3       2.25         2570      7242     2.0        2170
# 2         2       1.00          770     10000     1.0         770
# 3         4       3.00         1960      5000     1.0        1050
# 4         3       2.00         1680      8080     1.0        1680
#
#    sqft_basement
# 0              0
# 1            400
# 2              0
# 3            910
# 4              0

# %%
y = house['price']
y.head()
# Out:
# 0    221900.0
# 1    538000.0
# 2    180000.0
# 3    604000.0
# 4    510000.0
# Name: price, dtype: float64

# %%
x.shape
# Out:
# (21613, 7)

# %%
y.shape
# Out:
# (21613,)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
x_scaled = scaler.fit_transform(x)

# %%
x_scaled
# Out:
# array([[0.09090909, 0.125     , 0.06716981, ..., 0.        , 0.09758772,
#         0.        ],
#        [0.09090909, 0.28125   , 0.17207547, ..., 0.4       , 0.20614035,
#         0.08298755],
#        [0.06060606, 0.125     , 0.03622642, ..., 0.        , 0.05263158,
#         0.        ],
#        ...,
#        [0.06060606, 0.09375   , 0.05509434, ..., 0.4       , 0.08004386,
#         0.        ],
#        [0.09090909, 0.3125    , 0.09886792, ..., 0.4       , 0.14364035,
#         0.        ],
#        [0.06060606, 0.09375   , 0.05509434, ..., 0.4       , 0.08004386,
#         0.        ]])

# %%
x_scaled.shape
# Out:
# (21613, 7)

# %%
scaler.data_max_
# Out:
# array([3.300000e+01, 8.000000e+00, 1.354000e+04, 1.651359e+06,
#        3.500000e+00, 9.410000e+03, 4.820000e+03])

# %%
scaler.data_min_
# Out:
# array([  0.,   0., 290., 520.,   1., 290.,   0.])

# %%
y = y.values.reshape(-1, 1)

# %%
y.shape
# Out:
# (21613, 1)

# %%
y_scaled = scaler.fit_transform(y)

# %%
y_scaled
# Out:
# array([[0.01926557],
#        [0.06072131],
#        [0.01377049],
#        ...,
#        [0.04289849],
#        [0.04262295],
#        [0.03278689]])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y_scaled, test_size=0.25)

# %%
x_train.shape
# Out:
# (16209, 7)

# %%
x_test.shape
# Out:
# (5404, 7)

# %% [markdown]
# # Set and train the model

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(units=100, activation='relu', input_shape=(7, )))
model.add(tf.keras.layers.Dense(units=100, activation='relu'))
model.add(tf.keras.layers.Dense(units=100, activation='relu'))
model.add(tf.keras.layers.Dense(units=1, activation='linear'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               800
#
#  dense_1 (Dense)             (None, 100)               10100
#
#  dense_2 (Dense)             (None, 100)               10100
#
#  dense_3 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 21101 (82.43 KB)
# Trainable params: 21101 (82.43 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='Adam', loss='mean_squared_error')

# %%
epochs_hist = model.fit(x_train, y_train, epochs=100, batch_size=50, validation_split=0.2)
# Out:
# Epoch 1/100
# 260/260 [==============================] - 3s 5ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 2/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 3/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0010 - val_loss: 0.0012
# Epoch 4/100
# 260/260 [==============================] - 1s 2ms/step - loss: 0.0010 - val_loss: 0.0012
# Epoch 5/100
# 260/260 [==============================] - 1s 2ms/step - loss: 0.0010 - val_loss: 0.0014
# Epoch 6/100
# 260/260 [==============================] - 1s 2ms/step - loss: 9.8862e-04 - val_loss: 0.0012
# Epoch 7/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.9048e-04 - val_loss: 0.0012
# Epoch 8/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.8920e-04 - val_loss: 0.0012
# Epoch 9/100
# 260/260 [==============================] - 1s 4ms/step - loss: 9.7663e-04 - val_loss: 0.0012
# Epoch 10/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.6661e-04 - val_loss: 0.0012
# Epoch 11/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.7360e-04 - val_loss: 0.0011
# Epoch 12/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.6191e-04 - val_loss: 0.0012
# Epoch 13/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.6405e-04 - val_loss: 0.0012
# Epoch 14/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.5641e-04 - val_loss: 0.0011
# Epoch 15/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.4172e-04 - val_loss: 0.0012
# Epoch 16/100
# 260/260 [==============================] - 2s 7ms/step - loss: 9.5240e-04 - val_loss: 0.0011
# Epoch 17/100
# 260/260 [==============================] - 1s 5ms/step - loss: 9.5648e-04 - val_loss: 0.0012
# Epoch 18/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.5381e-04 - val_loss: 0.0012
# Epoch 19/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.5525e-04 - val_loss: 0.0013
# Epoch 20/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.5693e-04 - val_loss: 0.0011
# Epoch 21/100
# 260/260 [==============================] - 1s 2ms/step - loss: 9.3819e-04 - val_loss: 0.0012
# Epoch 22/100
# 260/260 [==============================] - 1s 2ms/step - loss: 9.3161e-04 - val_loss: 0.0012
# Epoch 23/100
# 260/260 [==============================] - 1s 2ms/step - loss: 9.5392e-04 - val_loss: 0.0012
# Epoch 24/100
# 260/260 [==============================] - 1s 2ms/step - loss: 9.4006e-04 - val_loss: 0.0012
# Epoch 25/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.3902e-04 - val_loss: 0.0012
# Epoch 26/100
# 260/260 [==============================] - 1s 4ms/step - loss: 9.2584e-04 - val_loss: 0.0011
# Epoch 27/100
# 260/260 [==============================] - 1s 2ms/step - loss: 9.3860e-04 - val_loss: 0.0011
# Epoch 28/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.2746e-04 - val_loss: 0.0013
# Epoch 29/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.4285e-04 - val_loss: 0.0012
# Epoch 30/100
# 260/260 [==============================] - 1s 2ms/step - loss: 9.2035e-04 - val_loss: 0.0011
# Epoch 31/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.4582e-04 - val_loss: 0.0011
# Epoch 32/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.1931e-04 - val_loss: 0.0012
# Epoch 33/100
# 260/260 [==============================] - 1s 4ms/step - loss: 9.1814e-04 - val_loss: 0.0011
# Epoch 34/100
# 260/260 [==============================] - 1s 4ms/step - loss: 9.2359e-04 - val_loss: 0.0011
# Epoch 35/100
# 260/260 [==============================] - 1s 4ms/step - loss: 9.1326e-04 - val_loss: 0.0011
# Epoch 36/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.3700e-04 - val_loss: 0.0011
# Epoch 37/100
# 260/260 [==============================] - 1s 2ms/step - loss: 9.1671e-04 - val_loss: 0.0011
# Epoch 38/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.0474e-04 - val_loss: 0.0012
# Epoch 39/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.1396e-04 - val_loss: 0.0011
# Epoch 40/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.1776e-04 - val_loss: 0.0011
# Epoch 41/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.0434e-04 - val_loss: 0.0011
# Epoch 42/100
# 260/260 [==============================] - 1s 2ms/step - loss: 9.0921e-04 - val_loss: 0.0011
# Epoch 43/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.1021e-04 - val_loss: 0.0011
# Epoch 44/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.1725e-04 - val_loss: 0.0011
# Epoch 45/100
# 260/260 [==============================] - 1s 2ms/step - loss: 9.0495e-04 - val_loss: 0.0012
# Epoch 46/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.2239e-04 - val_loss: 0.0011
# Epoch 47/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.1520e-04 - val_loss: 0.0011
# Epoch 48/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.2133e-04 - val_loss: 0.0011
# Epoch 49/100
# 260/260 [==============================] - 1s 2ms/step - loss: 9.0386e-04 - val_loss: 0.0011
# Epoch 50/100
# 260/260 [==============================] - 1s 2ms/step - loss: 9.0916e-04 - val_loss: 0.0011
# Epoch 51/100
# 260/260 [==============================] - 1s 4ms/step - loss: 9.1039e-04 - val_loss: 0.0011
# Epoch 52/100
# 260/260 [==============================] - 1s 4ms/step - loss: 9.2086e-04 - val_loss: 0.0011
# Epoch 53/100
# 260/260 [==============================] - 1s 4ms/step - loss: 9.0258e-04 - val_loss: 0.0011
# Epoch 54/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.0659e-04 - val_loss: 0.0011
# Epoch 55/100
# 260/260 [==============================] - 1s 2ms/step - loss: 9.1778e-04 - val_loss: 0.0011
# Epoch 56/100
# 260/260 [==============================] - 1s 2ms/step - loss: 8.9843e-04 - val_loss: 0.0011
# Epoch 57/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.1110e-04 - val_loss: 0.0011
# Epoch 58/100
# 260/260 [==============================] - 1s 2ms/step - loss: 9.0999e-04 - val_loss: 0.0011
# Epoch 59/100
# 260/260 [==============================] - 1s 2ms/step - loss: 8.9796e-04 - val_loss: 0.0011
# Epoch 60/100
# 260/260 [==============================] - 1s 2ms/step - loss: 9.0923e-04 - val_loss: 0.0012
# Epoch 61/100
# 260/260 [==============================] - 1s 2ms/step - loss: 9.0408e-04 - val_loss: 0.0011
# Epoch 62/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.9979e-04 - val_loss: 0.0011
# Epoch 63/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.9591e-04 - val_loss: 0.0012
# Epoch 64/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.9885e-04 - val_loss: 0.0011
# Epoch 65/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.8370e-04 - val_loss: 0.0011
# Epoch 66/100
# 260/260 [==============================] - 1s 2ms/step - loss: 8.9305e-04 - val_loss: 0.0011
# Epoch 67/100
# 260/260 [==============================] - 1s 5ms/step - loss: 8.8598e-04 - val_loss: 0.0012
# Epoch 68/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.9213e-04 - val_loss: 0.0011
# Epoch 69/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.9587e-04 - val_loss: 0.0011
# Epoch 70/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.9234e-04 - val_loss: 0.0011
# Epoch 71/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.9066e-04 - val_loss: 0.0011
# Epoch 72/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.8288e-04 - val_loss: 0.0011
# Epoch 73/100
# 260/260 [==============================] - 1s 2ms/step - loss: 8.8674e-04 - val_loss: 0.0011
# Epoch 74/100
# 260/260 [==============================] - 1s 2ms/step - loss: 8.8563e-04 - val_loss: 0.0011
# Epoch 75/100
# 260/260 [==============================] - 1s 2ms/step - loss: 8.8129e-04 - val_loss: 0.0012
# Epoch 76/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.9645e-04 - val_loss: 0.0011
# Epoch 77/100
# 260/260 [==============================] - 1s 2ms/step - loss: 8.8183e-04 - val_loss: 0.0011
# Epoch 78/100
# 260/260 [==============================] - 1s 2ms/step - loss: 8.7740e-04 - val_loss: 0.0011
# Epoch 79/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.8389e-04 - val_loss: 0.0011
# Epoch 80/100
# 260/260 [==============================] - 1s 2ms/step - loss: 8.9015e-04 - val_loss: 0.0011
# Epoch 81/100
# 260/260 [==============================] - 1s 2ms/step - loss: 8.8250e-04 - val_loss: 0.0011
# Epoch 82/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.8064e-04 - val_loss: 0.0011
# Epoch 83/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.7200e-04 - val_loss: 0.0011
# Epoch 84/100
# 260/260 [==============================] - 1s 2ms/step - loss: 8.6278e-04 - val_loss: 0.0011
# Epoch 85/100
# 260/260 [==============================] - 1s 2ms/step - loss: 8.6647e-04 - val_loss: 0.0011
# Epoch 86/100
# 260/260 [==============================] - 1s 2ms/step - loss: 8.7235e-04 - val_loss: 0.0011
# Epoch 87/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.6518e-04 - val_loss: 0.0011
# Epoch 88/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.7076e-04 - val_loss: 0.0012
# Epoch 89/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.6889e-04 - val_loss: 0.0011
# Epoch 90/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.8275e-04 - val_loss: 0.0011
# Epoch 91/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.7778e-04 - val_loss: 0.0011
# Epoch 92/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.6234e-04 - val_loss: 0.0011
# Epoch 93/100
# 260/260 [==============================] - 1s 2ms/step - loss: 8.5800e-04 - val_loss: 0.0011
# Epoch 94/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.5957e-04 - val_loss: 0.0011
# Epoch 95/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.7540e-04 - val_loss: 0.0011
# Epoch 96/100
# 260/260 [==============================] - 1s 2ms/step - loss: 8.6490e-04 - val_loss: 0.0011
# Epoch 97/100
# 260/260 [==============================] - 1s 2ms/step - loss: 8.5846e-04 - val_loss: 0.0011
# Epoch 98/100
# 260/260 [==============================] - 1s 2ms/step - loss: 8.7440e-04 - val_loss: 0.0011
# Epoch 99/100
# 260/260 [==============================] - 1s 2ms/step - loss: 8.6537e-04 - val_loss: 0.0011
# Epoch 100/100
# 260/260 [==============================] - 1s 2ms/step - loss: 8.5959e-04 - val_loss: 0.0012

# %% [markdown]
# # Assessment model

# %%
epochs_hist.history.keys()
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
plt.plot(epochs_hist.history['loss'])
plt.plot(epochs_hist.history['val_loss'])
plt.title('Model Loss Progress During Training')
plt.xlabel('Epoch')
plt.ylabel('Training and Validation Loss')
plt.legend(['Training Loss', 'Validation Loss']);

# %%
#bedrooms, bathrooms, sqft_living, sqft_lot, floors, sqft_above, sqft_basemenet
x_test_new = np.array([[4, 3, 1960, 5000, 1, 2000, 3000]])

scaler_new = MinMaxScaler()
x_test_new_scaled = scaler_new.fit_transform(x_test_new)

y_pred = model.predict(x_test_new_scaled)
y_pred_unscaled = scaler.inverse_transform(y_pred)
print(y_pred_unscaled)
# Out:
# 1/1 [==============================] - 0s 21ms/step
# [[192371.83]]

# %%
y_predict = model.predict(x_test)
plt.plot(y_test, y_predict, "^", color = 'r')
plt.xlabel('Model Predictions')
plt.ylabel('True Values');
# Out:
# 169/169 [==============================] - 1s 4ms/step

# %%
y_predict_orig = scaler.inverse_transform(y_predict)
y_test_orig = scaler.inverse_transform(y_test)

# %%
plt.plot(y_test_orig, y_predict_orig, "^", color = 'r')
plt.xlabel('Model Predictions')
plt.ylabel('True Values')
plt.xlim(0, 5000000)
plt.ylim(0, 3000000);

# %%
k = x_test.shape[1]
n = len(x_test)
n
# Out:
# 5404

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from math import sqrt

RMSE = float(format(np.sqrt(mean_squared_error(y_test_orig, y_predict_orig)),'.3f'))
MSE = mean_squared_error(y_test_orig, y_predict_orig)
MAE = mean_absolute_error(y_test_orig, y_predict_orig)
r2 = r2_score(y_test_orig, y_predict_orig)
adj_r2 = 1-(1-r2)*(n-1)/(n-k-1)

print('RMSE =',RMSE, '\nMSE =',MSE, '\nMAE =',MAE, '\nR2 =', r2, '\nAdjusted R2 =', adj_r2)
# Out:
# RMSE = 233914.478
# MSE = 54715982975.438126
# MAE = 151174.1436725111
# R2 = 0.5959714291271431
# Adjusted R2 = 0.5954473001434311

# %% [markdown]
# # More features

# %%
selected_features = ['bedrooms','bathrooms','sqft_living','sqft_lot','floors', 'sqft_above', 'sqft_basement', 'waterfront', 'view', 'condition', 'grade', 'sqft_above', 'yr_built',
'yr_renovated', 'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15']

X = house[selected_features]

# %%
X.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  sqft_above  \
# 0         3       1.00         1180      5650     1.0        1180
# 1         3       2.25         2570      7242     2.0        2170
# 2         2       1.00          770     10000     1.0         770
# 3         4       3.00         1960      5000     1.0        1050
# 4         3       2.00         1680      8080     1.0        1680
#
#    sqft_basement  waterfront  view  condition  grade  sqft_above  yr_built  \
# 0              0           0     0          3      7        1180      1955
# 1            400           0     0          3      7        2170      1951
# 2              0           0     0          3      6         770      1933
# 3            910           0     0          5      7        1050      1965
# 4              0           0     0          3      8        1680      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0             0    98178  47.5112 -122.257           1340        5650
# 1          1991    98125  47.7210 -122.319           1690        7639
# 2             0    98028  47.7379 -122.233           2720        8062
# 3             0    98136  47.5208 -122.393           1360        5000
# 4             0    98074  47.6168 -122.045           1800        7503

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_scaled
# Out:
# array([[0.09090909, 0.125     , 0.06716981, ..., 0.21760797, 0.16193426,
#         0.00574235],
#        [0.09090909, 0.28125   , 0.17207547, ..., 0.16611296, 0.22216486,
#         0.00802712],
#        [0.06060606, 0.125     , 0.03622642, ..., 0.23754153, 0.3994149 ,
#         0.00851302],
#        ...,
#        [0.06060606, 0.09375   , 0.05509434, ..., 0.18272425, 0.10686629,
#         0.00155764],
#        [0.09090909, 0.3125    , 0.09886792, ..., 0.37375415, 0.17398038,
#         0.00073057],
#        [0.06060606, 0.09375   , 0.05509434, ..., 0.18272425, 0.10686629,
#         0.00081098]])

# %%
y = house['price']

# %%
y = y.values.reshape(-1,1)
y_scaled = scaler.fit_transform(y)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size = 0.25)

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(units=100, activation='relu', input_shape=(19, )))
model.add(tf.keras.layers.Dense(units=100, activation='relu'))
model.add(tf.keras.layers.Dense(units=100, activation='relu'))
model.add(tf.keras.layers.Dense(units=1, activation='linear'))

# %%
model.compile(optimizer='Adam', loss='mean_squared_error')

# %%
epochs_hist = model.fit(X_train, y_train, epochs = 100, batch_size = 50, validation_split = 0.2)
# Out:
# Epoch 1/100
# 260/260 [==============================] - 2s 3ms/step - loss: 7.3729e-04 - val_loss: 8.2285e-04
# Epoch 2/100
# 260/260 [==============================] - 1s 3ms/step - loss: 4.9624e-04 - val_loss: 4.9642e-04
# Epoch 3/100
# 260/260 [==============================] - 1s 4ms/step - loss: 4.2794e-04 - val_loss: 5.7363e-04
# Epoch 4/100
# 260/260 [==============================] - 1s 4ms/step - loss: 3.9890e-04 - val_loss: 4.6053e-04
# Epoch 5/100
# 260/260 [==============================] - 1s 3ms/step - loss: 3.7421e-04 - val_loss: 4.0071e-04
# Epoch 6/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.6101e-04 - val_loss: 3.6346e-04
# Epoch 7/100
# 260/260 [==============================] - 1s 3ms/step - loss: 3.4421e-04 - val_loss: 3.8071e-04
# Epoch 8/100
# 260/260 [==============================] - 1s 4ms/step - loss: 3.0637e-04 - val_loss: 3.3967e-04
# Epoch 9/100
# 260/260 [==============================] - 1s 3ms/step - loss: 3.1150e-04 - val_loss: 3.4853e-04
# Epoch 10/100
# 260/260 [==============================] - 1s 2ms/step - loss: 2.8437e-04 - val_loss: 3.7188e-04
# Epoch 11/100
# 260/260 [==============================] - 1s 3ms/step - loss: 2.9855e-04 - val_loss: 3.7077e-04
# Epoch 12/100
# 260/260 [==============================] - 1s 3ms/step - loss: 2.8014e-04 - val_loss: 3.1728e-04
# Epoch 13/100
# 260/260 [==============================] - 1s 3ms/step - loss: 2.9455e-04 - val_loss: 4.9797e-04
# Epoch 14/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.1728e-04 - val_loss: 3.4722e-04
# Epoch 15/100
# 260/260 [==============================] - 1s 3ms/step - loss: 2.7895e-04 - val_loss: 3.9039e-04
# Epoch 16/100
# 260/260 [==============================] - 1s 3ms/step - loss: 2.7543e-04 - val_loss: 3.6200e-04
# Epoch 17/100
# 260/260 [==============================] - 1s 5ms/step - loss: 2.3539e-04 - val_loss: 3.5059e-04
# Epoch 18/100
# 260/260 [==============================] - 2s 6ms/step - loss: 2.4913e-04 - val_loss: 3.0500e-04
# Epoch 19/100
# 260/260 [==============================] - 2s 8ms/step - loss: 2.4366e-04 - val_loss: 3.4167e-04
# Epoch 20/100
# 260/260 [==============================] - 1s 4ms/step - loss: 2.3640e-04 - val_loss: 2.9091e-04
# Epoch 21/100
# 260/260 [==============================] - 1s 2ms/step - loss: 2.4407e-04 - val_loss: 3.4361e-04
# Epoch 22/100
# 260/260 [==============================] - 1s 2ms/step - loss: 2.3754e-04 - val_loss: 3.1153e-04
# Epoch 23/100
# 260/260 [==============================] - 1s 3ms/step - loss: 2.2329e-04 - val_loss: 2.8716e-04
# Epoch 24/100
# 260/260 [==============================] - 1s 3ms/step - loss: 2.4732e-04 - val_loss: 3.3341e-04
# Epoch 25/100
# 260/260 [==============================] - 1s 4ms/step - loss: 2.4318e-04 - val_loss: 3.8887e-04
# Epoch 26/100
# 260/260 [==============================] - 1s 4ms/step - loss: 2.1453e-04 - val_loss: 3.1497e-04
# Epoch 27/100
# 260/260 [==============================] - 1s 4ms/step - loss: 2.2049e-04 - val_loss: 3.1184e-04
# Epoch 28/100
# 260/260 [==============================] - 1s 4ms/step - loss: 2.3732e-04 - val_loss: 3.2589e-04
# Epoch 29/100
# 260/260 [==============================] - 1s 5ms/step - loss: 2.2952e-04 - val_loss: 3.1742e-04
# Epoch 30/100
# 260/260 [==============================] - 1s 3ms/step - loss: 2.2324e-04 - val_loss: 2.9059e-04
# Epoch 31/100
# 260/260 [==============================] - 1s 3ms/step - loss: 2.1430e-04 - val_loss: 2.8562e-04
# Epoch 32/100
# 260/260 [==============================] - 2s 7ms/step - loss: 2.1165e-04 - val_loss: 3.2982e-04
# Epoch 33/100
# 260/260 [==============================] - 2s 7ms/step - loss: 2.1565e-04 - val_loss: 3.3882e-04
# Epoch 34/100
# 260/260 [==============================] - 2s 6ms/step - loss: 2.2499e-04 - val_loss: 2.9896e-04
# Epoch 35/100
# 260/260 [==============================] - 1s 3ms/step - loss: 2.1922e-04 - val_loss: 2.7391e-04
# Epoch 36/100
# 260/260 [==============================] - 1s 2ms/step - loss: 2.0078e-04 - val_loss: 3.0566e-04
# Epoch 37/100
# 260/260 [==============================] - 1s 3ms/step - loss: 2.0527e-04 - val_loss: 2.6638e-04
# Epoch 38/100
# 260/260 [==============================] - 1s 3ms/step - loss: 1.9516e-04 - val_loss: 2.6351e-04
# Epoch 39/100
# 260/260 [==============================] - 1s 2ms/step - loss: 1.8806e-04 - val_loss: 2.5812e-04
# Epoch 40/100
# 260/260 [==============================] - 1s 3ms/step - loss: 1.9386e-04 - val_loss: 2.9562e-04
# Epoch 41/100
# 260/260 [==============================] - 1s 2ms/step - loss: 2.2917e-04 - val_loss: 2.9070e-04
# Epoch 42/100
# 260/260 [==============================] - 1s 2ms/step - loss: 2.0119e-04 - val_loss: 2.7640e-04
# Epoch 43/100
# 260/260 [==============================] - 1s 3ms/step - loss: 1.8499e-04 - val_loss: 2.8962e-04
# Epoch 44/100
# 260/260 [==============================] - 1s 3ms/step - loss: 1.7994e-04 - val_loss: 2.5987e-04
# Epoch 45/100
# 260/260 [==============================] - 1s 2ms/step - loss: 1.8503e-04 - val_loss: 2.7831e-04
# Epoch 46/100
# 260/260 [==============================] - 1s 2ms/step - loss: 1.8657e-04 - val_loss: 2.6474e-04
# Epoch 47/100
# 260/260 [==============================] - 1s 2ms/step - loss: 1.8714e-04 - val_loss: 2.6610e-04
# Epoch 48/100
# 260/260 [==============================] - 1s 2ms/step - loss: 1.7961e-04 - val_loss: 2.4873e-04
# Epoch 49/100
# 260/260 [==============================] - 1s 4ms/step - loss: 1.6804e-04 - val_loss: 2.5927e-04
# Epoch 50/100
# 260/260 [==============================] - 1s 4ms/step - loss: 1.6992e-04 - val_loss: 2.7490e-04
# Epoch 51/100
# 260/260 [==============================] - 1s 5ms/step - loss: 1.6644e-04 - val_loss: 2.6831e-04
# Epoch 52/100
# 260/260 [==============================] - 1s 3ms/step - loss: 1.6540e-04 - val_loss: 2.8355e-04
# Epoch 53/100
# 260/260 [==============================] - 1s 3ms/step - loss: 1.8661e-04 - val_loss: 3.8231e-04
# Epoch 54/100
# 260/260 [==============================] - 1s 3ms/step - loss: 1.8499e-04 - val_loss: 3.0181e-04
# Epoch 55/100
# 260/260 [==============================] - 1s 3ms/step - loss: 1.6476e-04 - val_loss: 2.7652e-04
# Epoch 56/100
# 260/260 [==============================] - 1s 2ms/step - loss: 1.6573e-04 - val_loss: 2.7891e-04
# Epoch 57/100
# 260/260 [==============================] - 1s 3ms/step - loss: 1.7781e-04 - val_loss: 2.7394e-04
# Epoch 58/100
# 260/260 [==============================] - 1s 3ms/step - loss: 1.7858e-04 - val_loss: 2.8047e-04
# Epoch 59/100
# 260/260 [==============================] - 1s 4ms/step - loss: 1.5562e-04 - val_loss: 2.9040e-04
# Epoch 60/100
# 260/260 [==============================] - 1s 3ms/step - loss: 1.5314e-04 - val_loss: 2.8467e-04
# Epoch 61/100
# 260/260 [==============================] - 1s 2ms/step - loss: 1.5957e-04 - val_loss: 2.8484e-04
# Epoch 62/100
# 260/260 [==============================] - 1s 3ms/step - loss: 1.5219e-04 - val_loss: 2.7590e-04
# Epoch 63/100
# 260/260 [==============================] - 1s 2ms/step - loss: 1.5804e-04 - val_loss: 3.2712e-04
# Epoch 64/100
# 260/260 [==============================] - 1s 2ms/step - loss: 1.6979e-04 - val_loss: 3.0199e-04
# Epoch 65/100
# 260/260 [==============================] - 1s 3ms/step - loss: 1.6570e-04 - val_loss: 2.9969e-04
# Epoch 66/100
# 260/260 [==============================] - 1s 3ms/step - loss: 1.6389e-04 - val_loss: 3.5179e-04
# Epoch 67/100
# 260/260 [==============================] - 1s 4ms/step - loss: 1.7026e-04 - val_loss: 3.0342e-04
# Epoch 68/100
# 260/260 [==============================] - 1s 4ms/step - loss: 1.5028e-04 - val_loss: 2.9202e-04
# Epoch 69/100
# 260/260 [==============================] - 1s 4ms/step - loss: 1.6034e-04 - val_loss: 2.8172e-04
# Epoch 70/100
# 260/260 [==============================] - 1s 3ms/step - loss: 1.4840e-04 - val_loss: 2.8994e-04
# Epoch 71/100
# 260/260 [==============================] - 1s 3ms/step - loss: 1.4384e-04 - val_loss: 2.8320e-04
# Epoch 72/100
# 260/260 [==============================] - 1s 2ms/step - loss: 1.4105e-04 - val_loss: 3.0169e-04
# Epoch 73/100
# 260/260 [==============================] - 1s 2ms/step - loss: 1.4448e-04 - val_loss: 2.8693e-04
# Epoch 74/100
# 260/260 [==============================] - 1s 3ms/step - loss: 1.4386e-04 - val_loss: 2.7491e-04
# Epoch 75/100
# 260/260 [==============================] - 1s 2ms/step - loss: 1.4260e-04 - val_loss: 2.9916e-04
# Epoch 76/100
# 260/260 [==============================] - 1s 3ms/step - loss: 1.5411e-04 - val_loss: 3.2671e-04
# Epoch 77/100
# 260/260 [==============================] - 1s 2ms/step - loss: 1.4755e-04 - val_loss: 2.9152e-04
# Epoch 78/100
# 260/260 [==============================] - 1s 3ms/step - loss: 1.3597e-04 - val_loss: 3.7903e-04
# Epoch 79/100
# 260/260 [==============================] - 1s 2ms/step - loss: 1.5065e-04 - val_loss: 2.9049e-04
# Epoch 80/100
# 260/260 [==============================] - 1s 2ms/step - loss: 1.3543e-04 - val_loss: 2.9268e-04
# Epoch 81/100
# 260/260 [==============================] - 1s 3ms/step - loss: 1.3488e-04 - val_loss: 2.7750e-04
# Epoch 82/100
# 260/260 [==============================] - 1s 3ms/step - loss: 1.4928e-04 - val_loss: 2.9606e-04
# Epoch 83/100
# 260/260 [==============================] - 1s 2ms/step - loss: 1.3904e-04 - val_loss: 2.9212e-04
# Epoch 84/100
# 260/260 [==============================] - 1s 3ms/step - loss: 1.3807e-04 - val_loss: 4.0642e-04
# Epoch 85/100
# 260/260 [==============================] - 1s 4ms/step - loss: 1.5944e-04 - val_loss: 2.9240e-04
# Epoch 86/100
# 260/260 [==============================] - 1s 4ms/step - loss: 1.3240e-04 - val_loss: 3.3050e-04
# Epoch 87/100
# 260/260 [==============================] - 1s 4ms/step - loss: 1.3088e-04 - val_loss: 3.2782e-04
# Epoch 88/100
# 260/260 [==============================] - 1s 3ms/step - loss: 1.2439e-04 - val_loss: 2.9543e-04
# Epoch 89/100
# 260/260 [==============================] - 1s 3ms/step - loss: 1.2479e-04 - val_loss: 3.0671e-04
# Epoch 90/100
# 260/260 [==============================] - 1s 2ms/step - loss: 1.4508e-04 - val_loss: 2.8177e-04
# Epoch 91/100
# 260/260 [==============================] - 1s 3ms/step - loss: 1.4005e-04 - val_loss: 3.0498e-04
# Epoch 92/100
# 260/260 [==============================] - 1s 3ms/step - loss: 1.3999e-04 - val_loss: 3.0966e-04
# Epoch 93/100
# 260/260 [==============================] - 1s 2ms/step - loss: 1.2007e-04 - val_loss: 2.9709e-04
# Epoch 94/100
# 260/260 [==============================] - 1s 3ms/step - loss: 1.2631e-04 - val_loss: 3.0124e-04
# Epoch 95/100
# 260/260 [==============================] - 1s 3ms/step - loss: 1.1636e-04 - val_loss: 3.0392e-04
# Epoch 96/100
# 260/260 [==============================] - 1s 2ms/step - loss: 1.3004e-04 - val_loss: 3.0976e-04
# Epoch 97/100
# 260/260 [==============================] - 1s 3ms/step - loss: 1.3851e-04 - val_loss: 3.1604e-04
# Epoch 98/100
# 260/260 [==============================] - 1s 3ms/step - loss: 1.3595e-04 - val_loss: 3.3807e-04
# Epoch 99/100
# 260/260 [==============================] - 1s 3ms/step - loss: 1.3614e-04 - val_loss: 2.8872e-04
# Epoch 100/100
# 260/260 [==============================] - 1s 2ms/step - loss: 1.2178e-04 - val_loss: 2.9461e-04

# %%
plt.plot(epochs_hist.history['loss'])
plt.plot(epochs_hist.history['val_loss'])
plt.title('Model Loss Progress During Training')
plt.ylabel('Training and Validation Loss')
plt.xlabel('Epoch number')
plt.legend(['Training Loss', 'Validation Loss']);

# %%
y_predict = model.predict(X_test)
plt.plot(y_test, y_predict, "^", color = 'r')
plt.xlabel("Model Predictions")
plt.ylabel("True Value (ground Truth)")
plt.title('Linear Regression Predictions')
plt.show()
# Out:
# 169/169 [==============================] - 0s 2ms/step

# %%
y_predict_orig = scaler.inverse_transform(y_predict)
y_test_orig = scaler.inverse_transform(y_test)

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from math import sqrt

RMSE = float(format(np.sqrt(mean_squared_error(y_test_orig, y_predict_orig)),'.3f'))
MSE = mean_squared_error(y_test_orig, y_predict_orig)
MAE = mean_absolute_error(y_test_orig, y_predict_orig)
r2 = r2_score(y_test_orig, y_predict_orig)
adj_r2 = 1-(1-r2)*(n-1)/(n-k-1)

print('RMSE =',RMSE, '\nMSE =',MSE, '\nMAE =',MAE, '\nR2 =', r2, '\nAdjusted R2 =', adj_r2)
# Out:
# RMSE = 126588.807
# MSE = 16024726085.255745
# MAE = 70904.98512386659
# R2 = 0.8729825420262273
# Adjusted R2 = 0.8728177677108424
