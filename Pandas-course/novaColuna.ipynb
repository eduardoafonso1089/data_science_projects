# %%
import pandas as pd
import numpy as np

# %%
datas = pd.date_range('20190101', periods = 60, freq = 'D')

df = pd.DataFrame(np.random.randn(60, 5), index = datas, columns = list('ABCDE'))

# %%
df.shape
# Out:
# (60, 5)

# %%
df.head(3)
# Out:
#                    A         B         C         D         E
# 2019-01-01  0.662043  1.083669  0.536741  1.816191 -0.242409
# 2019-01-02  0.550125  1.730185 -0.599626 -1.655865  0.031521
# 2019-01-03  0.478827 -1.771805 -1.360932  0.063394  0.132412

# %%
df["F"] = 1

# %%
df.head(10)
# Out:
#                    A         B         C         D         E  F
# 2019-01-01  0.662043  1.083669  0.536741  1.816191 -0.242409  1
# 2019-01-02  0.550125  1.730185 -0.599626 -1.655865  0.031521  1
# 2019-01-03  0.478827 -1.771805 -1.360932  0.063394  0.132412  1
# 2019-01-04 -0.129794  2.316154  0.525047  0.170192 -1.817008  1
# 2019-01-05  0.975737  0.199147  1.208197 -1.647327  1.217395  1
# 2019-01-06 -0.780036  1.359502 -1.711786 -0.813358 -0.161812  1
# 2019-01-07  0.161693 -0.526413  1.012463  0.967036  0.313270  1
# 2019-01-08 -0.055679 -0.657737  0.466684 -1.347474 -0.204633  1
# 2019-01-09  0.219001  0.008921 -1.225203 -0.991048 -0.399071  1
# 2019-01-10 -0.501499  0.022603 -1.123883 -2.000279 -0.583792  1

# %%
df["G"] = range(60)
df.head(10)
# Out:
#                    A         B         C         D         E  F  G
# 2019-01-01  0.662043  1.083669  0.536741  1.816191 -0.242409  1  0
# 2019-01-02  0.550125  1.730185 -0.599626 -1.655865  0.031521  1  1
# 2019-01-03  0.478827 -1.771805 -1.360932  0.063394  0.132412  1  2
# 2019-01-04 -0.129794  2.316154  0.525047  0.170192 -1.817008  1  3
# 2019-01-05  0.975737  0.199147  1.208197 -1.647327  1.217395  1  4
# 2019-01-06 -0.780036  1.359502 -1.711786 -0.813358 -0.161812  1  5
# 2019-01-07  0.161693 -0.526413  1.012463  0.967036  0.313270  1  6
# 2019-01-08 -0.055679 -0.657737  0.466684 -1.347474 -0.204633  1  7
# 2019-01-09  0.219001  0.008921 -1.225203 -0.991048 -0.399071  1  8
# 2019-01-10 -0.501499  0.022603 -1.123883 -2.000279 -0.583792  1  9

# %%
df["Produto"] = df['A'] * df['B']
df.head(3)
# Out:
#                    A         B         C         D         E  F  G   Produto
# 2019-01-01  0.662043  1.083669  0.536741  1.816191 -0.242409  1  0  0.717435
# 2019-01-02  0.550125  1.730185 -0.599626 -1.655865  0.031521  1  1  0.951817
# 2019-01-03  0.478827 -1.771805 -1.360932  0.063394  0.132412  1  2 -0.848388

# %%
df['D'] = 88
df.head(3)
# Out:
#                    A         B         C   D         E  F  G   Produto
# 2019-01-01  0.662043  1.083669  0.536741  88 -0.242409  1  0  0.717435
# 2019-01-02  0.550125  1.730185 -0.599626  88  0.031521  1  1  0.951817
# 2019-01-03  0.478827 -1.771805 -1.360932  88  0.132412  1  2 -0.848388
