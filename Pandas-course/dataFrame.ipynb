# %%
import pandas as pd
import numpy as np

# %%
series = pd.Series([7, 4, 2, np.nan, 6, 9])

# %%
series
# Out:
# 0    7.0
# 1    4.0
# 2    2.0
# 3    NaN
# 4    6.0
# 5    9.0
# dtype: float64

# %%
type(series)
# Out:
# pandas.core.series.Series

# %%
datas = pd.date_range('20180101', periods=6)

# %%
datas
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-02', '2018-01-03', '2018-01-04',
#                '2018-01-05', '2018-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
type(datas)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
df = pd.DataFrame(np.random.randn(6,4), index = datas, columns= list('ABCD'))

# %%
df
# Out:
#                    A         B         C         D
# 2018-01-01 -1.976960 -0.147394 -0.752676 -0.268356
# 2018-01-02  2.277400 -1.402787  0.267787 -0.695471
# 2018-01-03 -1.222910 -0.865765 -0.201074  1.477978
# 2018-01-04 -0.041585 -0.811096 -0.686508 -1.107973
# 2018-01-05 -1.583286  0.912783  0.400611  0.677688
# 2018-01-06  0.316584 -1.028492  0.056006 -0.535946

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df2 = pd.DataFrame({"A" : 7,
                    "B" : pd.Timestamp('20190101'),
                    "C" : pd.Series(1, index=list(range(4)), dtype='float32'),
                    'D' : np.array([3] * 4, dtype="int32"),
                    "E" : pd.Categorical(["test", "train", "test", "train"]),
                    "F" : "Python"})

# %%
df2
# Out:
#    A          B    C  D      E       F
# 0  7 2019-01-01  1.0  3   test  Python
# 1  7 2019-01-01  1.0  3  train  Python
# 2  7 2019-01-01  1.0  3   test  Python
# 3  7 2019-01-01  1.0  3  train  Python

# %%
df2.dtypes
# Out:
# A             int64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df.tail()
# Out:
#                    A         B         C         D
# 2018-01-02  2.277400 -1.402787  0.267787 -0.695471
# 2018-01-03 -1.222910 -0.865765 -0.201074  1.477978
# 2018-01-04 -0.041585 -0.811096 -0.686508 -1.107973
# 2018-01-05 -1.583286  0.912783  0.400611  0.677688
# 2018-01-06  0.316584 -1.028492  0.056006 -0.535946

# %%
df.index
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-02', '2018-01-03', '2018-01-04',
#                '2018-01-05', '2018-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
c = df.columns

# %%
df.to_numpy()
# Out:
# array([[-1.97696018, -0.14739404, -0.75267592, -0.26835604],
#        [ 2.27739987, -1.40278684,  0.26778657, -0.69547087],
#        [-1.22291016, -0.86576529, -0.20107367,  1.47797808],
#        [-0.04158539, -0.8110959 , -0.68650755, -1.10797311],
#        [-1.58328616,  0.91278265,  0.40061114,  0.67768797],
#        [ 0.31658405, -1.02849208,  0.05600568, -0.53594555]])

# %%
df.T
# Out:
#    2018-01-01  2018-01-02  2018-01-03  2018-01-04  2018-01-05  2018-01-06
# A   -1.976960    2.277400   -1.222910   -0.041585   -1.583286    0.316584
# B   -0.147394   -1.402787   -0.865765   -0.811096    0.912783   -1.028492
# C   -0.752676    0.267787   -0.201074   -0.686508    0.400611    0.056006
# D   -0.268356   -0.695471    1.477978   -1.107973    0.677688   -0.535946

# %%
df2.T
# Out:
#                      0                    1                    2  \
# A                    7                    7                    7
# B  2019-01-01 00:00:00  2019-01-01 00:00:00  2019-01-01 00:00:00
# C                  1.0                  1.0                  1.0
# D                    3                    3                    3
# E                 test                train                 test
# F               Python               Python               Python
#
#                      3
# A                    7
# B  2019-01-01 00:00:00
# C                  1.0
# D                    3
# E                train
# F               Python

# %%
df2.to_numpy()
# Out:
# array([[7, Timestamp('2019-01-01 00:00:00'), 1.0, 3, 'test', 'Python'],
#        [7, Timestamp('2019-01-01 00:00:00'), 1.0, 3, 'train', 'Python'],
#        [7, Timestamp('2019-01-01 00:00:00'), 1.0, 3, 'test', 'Python'],
#        [7, Timestamp('2019-01-01 00:00:00'), 1.0, 3, 'train', 'Python']],
#       dtype=object)
