# %%
import pandas as pd
import numpy as np

# %%
datas = pd.date_range('2018-01-01', periods=600)

df = pd.DataFrame(np.random.randn(600, 5), index=datas, columns=list('ABCDE'))

# %%
df.head(2)
# Out:
#                    A         B         C         D         E
# 2018-01-01  1.073625 -1.113645 -1.508319  0.972765 -0.254540
# 2018-01-02  0.537743 -1.563652  0.779919 -0.375474 -1.074379

# %%
df['D'].head(5)
# Out:
# 2018-01-01    0.972765
# 2018-01-02   -0.375474
# 2018-01-03    0.853554
# 2018-01-04   -0.027212
# 2018-01-05    0.561267
# Freq: D, Name: D, dtype: float64

# %%
df[1:5]
# Out:
#                    A         B         C         D         E
# 2018-01-02  0.537743 -1.563652  0.779919 -0.375474 -1.074379
# 2018-01-03 -0.192195  1.839683 -0.235900  0.853554 -0.809120
# 2018-01-04  0.691925 -0.330275  2.368481 -0.027212  0.019454
# 2018-01-05 -2.048824 -1.085876  0.704315  0.561267 -1.610859

# %%
df.loc[:, ['B', 'C', 'D']]
# Out:
#                    B         C         D
# 2018-01-01 -1.113645 -1.508319  0.972765
# 2018-01-02 -1.563652  0.779919 -0.375474
# 2018-01-03  1.839683 -0.235900  0.853554
# 2018-01-04 -0.330275  2.368481 -0.027212
# 2018-01-05 -1.085876  0.704315  0.561267
# ...              ...       ...       ...
# 2019-08-19 -0.462452  1.362003 -1.428691
# 2019-08-20  0.306342 -1.183416 -0.711485
# 2019-08-21  0.412628  0.902543 -0.207700
# 2019-08-22 -0.983202  1.250510  0.146424
# 2019-08-23  1.538281 -0.726306  0.603214
#
# [600 rows x 3 columns]

# %%
df.head(3)
# Out:
#                    A         B         C         D         E
# 2018-01-01  1.073625 -1.113645 -1.508319  0.972765 -0.254540
# 2018-01-02  0.537743 -1.563652  0.779919 -0.375474 -1.074379
# 2018-01-03 -0.192195  1.839683 -0.235900  0.853554 -0.809120

# %%
f = df.loc['20180301': '20180917', ['A', 'E']]

# %%
len(f)
# Out:
# 201

# %%
df.iloc[1:4, 1:3]
# Out:
#                    B         C
# 2018-01-02 -1.563652  0.779919
# 2018-01-03  1.839683 -0.235900
# 2018-01-04 -0.330275  2.368481

# %%
df.iloc[[1,5,6], [0,3]]
# Out:
#                    A         D
# 2018-01-02  0.537743 -0.375474
# 2018-01-06 -0.736813  0.509329
# 2018-01-07  0.091540  0.829169

# %%
df.iloc[1:3, :]
# Out:
#                    A         B         C         D         E
# 2018-01-02  0.537743 -1.563652  0.779919 -0.375474 -1.074379
# 2018-01-03 -0.192195  1.839683 -0.235900  0.853554 -0.809120

# %%
df.head()
# Out:
#                    A         B         C         D         E
# 2018-01-01  1.073625 -1.113645 -1.508319  0.972765 -0.254540
# 2018-01-02  0.537743 -1.563652  0.779919 -0.375474 -1.074379
# 2018-01-03 -0.192195  1.839683 -0.235900  0.853554 -0.809120
# 2018-01-04  0.691925 -0.330275  2.368481 -0.027212  0.019454
# 2018-01-05 -2.048824 -1.085876  0.704315  0.561267 -1.610859

# %%
df.A
# Out:
# 2018-01-01    1.073625
# 2018-01-02    0.537743
# 2018-01-03   -0.192195
# 2018-01-04    0.691925
# 2018-01-05   -2.048824
#                 ...
# 2019-08-19   -0.800813
# 2019-08-20   -0.427648
# 2019-08-21    0.809874
# 2019-08-22    0.914332
# 2019-08-23   -0.509889
# Freq: D, Name: A, Length: 600, dtype: float64

# %%
df.iloc[0, :].values
# Out:
# array([ 1.07362461, -1.11364522, -1.50831914,  0.97276455, -0.25453957])

# %%
df[df > 0]
# Out:
#                    A         B         C         D         E
# 2018-01-01  1.073625       NaN       NaN  0.972765       NaN
# 2018-01-02  0.537743       NaN  0.779919       NaN       NaN
# 2018-01-03       NaN  1.839683       NaN  0.853554       NaN
# 2018-01-04  0.691925       NaN  2.368481       NaN  0.019454
# 2018-01-05       NaN       NaN  0.704315  0.561267       NaN
# ...              ...       ...       ...       ...       ...
# 2019-08-19       NaN       NaN  1.362003       NaN  0.941876
# 2019-08-20       NaN  0.306342       NaN       NaN  1.103336
# 2019-08-21  0.809874  0.412628  0.902543       NaN       NaN
# 2019-08-22  0.914332       NaN  1.250510  0.146424  0.468913
# 2019-08-23       NaN  1.538281       NaN  0.603214  0.610172
#
# [600 rows x 5 columns]
