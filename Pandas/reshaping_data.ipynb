# %%
import pandas as pd
import numpy as np

# %%
datas = pd.date_range('2020-01-01', periods=6)

df = pd.DataFrame(np.random.randn(6, 4), index=datas, columns=list(['Var_A', 'Var_B', 'Var_C', 'Var_D']))
df
# Out:
#                Var_A     Var_B     Var_C     Var_D
# 2020-01-01 -0.558167 -0.418278 -1.209052 -0.833194
# 2020-01-02 -0.807400 -0.154675 -0.442645 -1.313155
# 2020-01-03  1.066670  0.641520 -0.319598  1.767254
# 2020-01-04  0.280658 -0.928005  0.663982 -0.007207
# 2020-01-05 -1.153923 -0.490052  0.557107  0.319198
# 2020-01-06  0.426928 -0.847010 -0.440710 -0.346584

# %%
dft = df.T

# %%
df.shape
# Out:
# (6, 4)

# %%
dft.shape
# Out:
# (4, 6)

# %%
np.size(dft.values)
# Out:
# 24

# %%
dft.values
# Out:
# array([[-0.55816733, -0.80740049,  1.06667029,  0.28065782, -1.15392286,
#          0.42692777],
#        [-0.41827784, -0.15467468,  0.64152004, -0.92800486, -0.49005175,
#         -0.84701011],
#        [-1.20905162, -0.44264527, -0.31959777,  0.66398185,  0.55710746,
#         -0.44071039],
#        [-0.83319446, -1.31315508,  1.76725421, -0.00720726,  0.31919846,
#         -0.34658403]])

# %%
v = dft.values

# %%
v.reshape((2,12))
# Out:
# array([[-0.55816733, -0.80740049,  1.06667029,  0.28065782, -1.15392286,
#          0.42692777, -0.41827784, -0.15467468,  0.64152004, -0.92800486,
#         -0.49005175, -0.84701011],
#        [-1.20905162, -0.44264527, -0.31959777,  0.66398185,  0.55710746,
#         -0.44071039, -0.83319446, -1.31315508,  1.76725421, -0.00720726,
#          0.31919846, -0.34658403]])

# %% [markdown]
# # Função Pivot

# %%
dias = pd.date_range('2019-01-01', periods=12)

# %%
Pessoa = ['George', 'Victor', 'Lucas']

# %%
np.random.choice(Pessoa)
# Out:
# 'Victor'

# %%
Nome = []
Gasto = []

for i in range(12):
  Nome.append(np.random.choice(Pessoa))
  Gasto.append(np.round(np.random.rand()*100, 2))

Nome
# Out:
# ['Lucas',
#  'Victor',
#  'George',
#  'George',
#  'Lucas',
#  'Victor',
#  'George',
#  'George',
#  'George',
#  'Victor',
#  'George',
#  'Lucas']

# %%
Gasto
# Out:
# [97.75,
#  77.31,
#  97.51,
#  66.88,
#  35.67,
#  97.44,
#  38.63,
#  67.73,
#  86.24,
#  64.22,
#  17.76,
#  25.9]

# %%
df = pd.DataFrame({'Dia' : dias,'Nome': Nome, 'Gasto': Gasto})

# %%
df
# Out:
#           Dia    Nome  Gasto
# 0  2019-01-01   Lucas  97.75
# 1  2019-01-02  Victor  77.31
# 2  2019-01-03  George  97.51
# 3  2019-01-04  George  66.88
# 4  2019-01-05   Lucas  35.67
# 5  2019-01-06  Victor  97.44
# 6  2019-01-07  George  38.63
# 7  2019-01-08  George  67.73
# 8  2019-01-09  George  86.24
# 9  2019-01-10  Victor  64.22
# 10 2019-01-11  George  17.76
# 11 2019-01-12   Lucas  25.90

# %%
df.pivot(index='Dia', columns='Nome', values='Gasto')
# Out:
# Nome        George  Lucas  Victor
# Dia
# 2019-01-01     NaN  97.75     NaN
# 2019-01-02     NaN    NaN   77.31
# 2019-01-03   97.51    NaN     NaN
# 2019-01-04   66.88    NaN     NaN
# 2019-01-05     NaN  35.67     NaN
# 2019-01-06     NaN    NaN   97.44
# 2019-01-07   38.63    NaN     NaN
# 2019-01-08   67.73    NaN     NaN
# 2019-01-09   86.24    NaN     NaN
# 2019-01-10     NaN    NaN   64.22
# 2019-01-11   17.76    NaN     NaN
# 2019-01-12     NaN  25.90     NaN

# %% [markdown]
# # Pivot table

# %%
Carros = [7,4,3,2,8]
dias = pd.date_range('2019-01-01', '20190101', periods=5)

vendedor = ['George', 'Vagner', 'Pedro', 'Vagner', 'George']

df = pd.DataFrame({'Vendas': Carros, 'Data': dias, 'Vendedor': vendedor})

# %%
df
# Out:
#    Vendas       Data Vendedor
# 0       7 2019-01-01   George
# 1       4 2019-01-01   Vagner
# 2       3 2019-01-01    Pedro
# 3       2 2019-01-01   Vagner
# 4       8 2019-01-01   George

# %%
pd.pivot(df, values='Vendas', index='Data', columns='Vendedor')
#ERRO!

# %%
pd.pivot_table(df, values='Vendas', index='Data', columns='Vendedor', aggfunc="sum")
# Out:
# Vendedor    George  Pedro  Vagner
# Data
# 2019-01-01      15      3       6
