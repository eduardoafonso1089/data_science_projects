# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({'A': ['verdadeiro', 'falso', 'verdadeiro', 'falso', 'verdadeiro', 'falso', 'verdadeiro', 'falso'],
                   'B': ['um', 'um', 'dois', 'tres', 'um', 'dois', 'dois', 'tres'],
                   'C' : np.random.randn(8),
                   'D' : np.random.randn(8)})

# %%
df
# Out:
#             A     B         C         D
# 0  verdadeiro    um  0.587389 -0.666543
# 1       falso    um  1.816550  0.138035
# 2  verdadeiro  dois -0.783440  2.998476
# 3       falso  tres  0.353114  0.782956
# 4  verdadeiro    um  0.359599  0.374411
# 5       falso  dois  1.378628 -0.242062
# 6  verdadeiro  dois -1.462481  0.302909
# 7       falso  tres  0.159449  0.214100

# %%
df.groupby(['A']).sum(numeric_only=True)
# Out:
#                    C         D
# A
# falso       3.707740  0.893028
# verdadeiro -1.298932  3.009252

# %%
df.groupby(['A']).mean(numeric_only=True)
# Out:
#                    C         D
# A
# falso       0.926935  0.223257
# verdadeiro -0.324733  0.752313

# %%
df.groupby(['B']).sum(numeric_only=True)
# Out:
#              C         D
# B
# dois -0.867293  3.059322
# tres  0.512562  0.997056
# um    2.763538 -0.154098

# %%
df.groupby(['B']).mean(numeric_only=True)
# Out:
#              C         D
# B
# dois -0.289098  1.019774
# tres  0.256281  0.498528
# um    0.921179 -0.051366

# %%
df.groupby(['A', 'B']).sum(numeric_only=True)
# Out:
#                         C         D
# A          B
# falso      dois  1.378628 -0.242062
#            tres  0.512562  0.997056
#            um    1.816550  0.138035
# verdadeiro dois -2.245920  3.301385
#            um    0.946988 -0.292133
