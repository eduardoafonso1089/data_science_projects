# %%
import pandas as pd
import numpy as np

# %%
datas = pd.date_range('20200101', periods=6)

df = pd.DataFrame(np.random.randn(6, 4), index=datas, columns=['Var_A', 'Var_B', 'Var_C', 'Var_D'])

# %%
df2 = pd.DataFrame({'A':1.,
                    'B' : pd.Timestamp('20130102'),
                    'C': pd.Series(1, index=list(range(4)), dtype='float32'),
                    'D': np.array([3]*4, dtype='int32'),
                    'E': pd.Categorical(['test', 'train', 'test', 'train']),
                    'F': 'Python'})

# %%
df.shape
# Out:
# (6, 4)

# %%
df.dtypes
# Out:
# Var_A    float64
# Var_B    float64
# Var_C    float64
# Var_D    float64
# dtype: object

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df2.describe()
# Out:
#          A                    B    C    D
# count  4.0                    4  4.0  4.0
# mean   1.0  2013-01-02 00:00:00  1.0  3.0
# min    1.0  2013-01-02 00:00:00  1.0  3.0
# 25%    1.0  2013-01-02 00:00:00  1.0  3.0
# 50%    1.0  2013-01-02 00:00:00  1.0  3.0
# 75%    1.0  2013-01-02 00:00:00  1.0  3.0
# max    1.0  2013-01-02 00:00:00  1.0  3.0
# std    0.0                  NaN  0.0  0.0

# %%
df1 = df.reindex(index=datas[0:4], columns=list(df.columns) + ['Var_E'])

# %%
df1
# Out:
#                Var_A     Var_B     Var_C     Var_D  Var_E
# 2020-01-01  0.203252 -0.413740 -0.439296 -0.477506    NaN
# 2020-01-02  0.786706  0.811778 -1.158338  0.971220    NaN
# 2020-01-03 -2.000735 -1.335855 -0.236710 -0.569502    NaN
# 2020-01-04  0.059988 -0.197847 -1.094770  0.618838    NaN

# %%
df1.loc[datas[0]:datas[1], 'Var_E'] = 77

# %%
df1
# Out:
#                Var_A     Var_B     Var_C     Var_D  Var_E
# 2020-01-01  0.203252 -0.413740 -0.439296 -0.477506   77.0
# 2020-01-02  0.786706  0.811778 -1.158338  0.971220   77.0
# 2020-01-03 -2.000735 -1.335855 -0.236710 -0.569502    NaN
# 2020-01-04  0.059988 -0.197847 -1.094770  0.618838    NaN

# %%
df1.dtypes
# Out:
# Var_A    float64
# Var_B    float64
# Var_C    float64
# Var_D    float64
# Var_E    float64
# dtype: object

# %%
df1.describe()
# Out:
#           Var_A     Var_B     Var_C     Var_D  Var_E
# count  4.000000  4.000000  4.000000  4.000000    2.0
# mean  -0.237697 -0.283916 -0.732279  0.135763   77.0
# std    1.216656  0.881548  0.463448  0.775639    0.0
# min   -2.000735 -1.335855 -1.158338 -0.569502   77.0
# 25%   -0.455193 -0.644269 -1.110662 -0.500505   77.0
# 50%    0.131620 -0.305793 -0.767033  0.070666   77.0
# 75%    0.349116  0.054559 -0.388650  0.706934   77.0
# max    0.786706  0.811778 -0.236710  0.971220   77.0
